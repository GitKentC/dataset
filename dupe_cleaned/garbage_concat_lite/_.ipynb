# %%
import os
from PIL import Image

# Set the base directory where your folders are located
base_dir = '.'

# Iterate through all folders
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)

    # Check if the current path is a directory
    if os.path.isdir(folder_path):
        # Iterate through all files in the folder
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            
            # Process only .jpg files
            if file_name.lower().endswith('.jpg'):
                try:
                    # Open the image
                    with Image.open(file_path) as img:
                        # Get original dimensions
                        width, height = img.size
                        
                        # Determine the scaling factor
                        if max(width, height) > 256:
                            if width >= height:
                                new_width = 256
                                new_height = int((height / width) * 256)
                            else:
                                new_height = 256
                                new_width = int((width / height) * 256)

                            # Resize the image
                            img_resized = img.resize((new_width, new_height), Image.Resampling.LANCZOS)

                            # Save the resized image, overwriting the original
                            img_resized.save(file_path)
                            print(f"Resized: {file_path}")
                        else:
                            print(f"Skipped (already smaller): {file_path}")
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")

print("Image resizing completed.")
# Out:
# Resized: .\battery\battery0001.jpg
# Skipped (already smaller): .\battery\battery0002.jpg
# Skipped (already smaller): .\battery\battery0003.jpg
# Resized: .\battery\battery0004.jpg
# Skipped (already smaller): .\battery\battery0005.jpg
# Skipped (already smaller): .\battery\battery0006.jpg
# Resized: .\battery\battery0007.jpg
# Skipped (already smaller): .\battery\battery0008.jpg
# Skipped (already smaller): .\battery\battery0009.jpg
# Resized: .\battery\battery0010.jpg
# Skipped (already smaller): .\battery\battery0011.jpg
# Skipped (already smaller): .\battery\battery0012.jpg
# Resized: .\battery\battery0013.jpg
# Skipped (already smaller): .\battery\battery0014.jpg
# Resized: .\battery\battery0015.jpg
# Resized: .\battery\battery0016.jpg
# Resized: .\battery\battery0017.jpg
# Resized: .\battery\battery0018.jpg
# Skipped (already smaller): .\battery\battery0019.jpg
# Resized: .\battery\battery0020.jpg
# Resized: .\battery\battery0021.jpg
# ...

# %%
import os
import random
import shutil

# Path to the main dataset folder
dataset_dir = 'C:/capstone/dataset_experiment/dupe_cleaned/garbage_concat'

# Loop through all subfolders in the dataset
for folder_name in os.listdir(dataset_dir):
    folder_path = os.path.join(dataset_dir, folder_name)
    
    # Check if it's a directory
    if os.path.isdir(folder_path):
        # Get a list of all image files in the subfolder
        images = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
        num_images = len(images)
        
        # If there are more than 850 images, we need to randomly delete some
        if num_images > 850:
            # Calculate how many images to delete
            num_to_delete = num_images - 850
            
            # Randomly select files to delete
            files_to_delete = random.sample(images, num_to_delete)
            
            for file in files_to_delete:
                file_path = os.path.join(folder_path, file)
                os.remove(file_path)  # Delete the file
                print(f"Deleted {file} from {folder_name}")

print("Dataset balancing complete.")
# Out:
# Dataset balancing complete.

# %%
import os
os.listdir('./dataset_experiment/dupe_cleaned/garbage_concat')
# Out:
# ['battery',
#  'biological',
#  'brown-glass',
#  'bulb',
#  'cardboard',
#  'ceramic',
#  'clothes',
#  'diaper',
#  'drugs',
#  'green-glass',
#  'leftovers',
#  'mask',
#  'metal',
#  'paper',
#  'plastic',
#  'shoes',
#  'toothbrush',
#  'white-glass',
#  '_.ipynb']
