# %%
import os
import imagehash
import random
import shutil
from PIL import Image
from pathlib import Path

# %%
""" GLOBAL VARIABLES """
DATA_DIR: Path = Path("C:/capstone/dataset/raw")
EXTENSIONS: list[str] = [".png", ".jpg", ".jpeg", ".bmp", ".gif"]
# WHERE_IS_YOUR_DATASET: str = '...'

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## CHECK DUPLICATES FOR EACH CLASS

# %% [markdown]
# This only check duplicates for each class assuming you provide DATA_DIR path to a folder consisting subfolders, example:
# ```
# DATA_DIR
# ├───subfolder_1
# │   ├───class_1
# │   ├───...
# │   └───class_n
# └───subfolder_n
#     ├───class_1
#     ├─── ...
#     └───class_n
# ```
# This is tipically what's available on Kaggle

# %%
from imagehash import ImageHash


def print_log(duplicates_log: dict[str, list[tuple[str, str]]], 
                   total_duplicates: dict[str, int]) -> None:
    """ Print duplicate images and counts per subfolder """
    if duplicates_log:
        print("\nDuplicate images found:")
        for class_name, duplicate_pairs in duplicates_log.items():
            print(f"\nClass: {class_name}")
            for duplicate, original in duplicate_pairs:
                print(f"Duplicate: {duplicate} | Original: {original}")
        
        print("\nTotal duplicates found per subfolder:")
        for subfolder, count in total_duplicates.items():
            print(f"{subfolder}: {count}")
    else:
        print("No duplicates found in log; \
              Duplicates log not found")
        
def check_structure(where_is_your_ds: str) -> None:
    if 'dataset' not in os.listdir():
        _path = os.path.join('dataset', 'raw')
        os.mkdir(_path)
        if os.path.exists(where_is_your_ds):
            shutil.move(where_is_your_ds, _path)
    
def check_for_dupes(ds_dir: Path):
    """ Check for duplicate images in the dataset """
    duplicates_log: dict[str, list[tuple[str, str]]] = {} # ini simpen Path duplicatenya
    total_duplicates: dict[str, int] = {subfolder.name: 0 for subfolder \
                                        in ds_dir.iterdir() if subfolder.is_dir()}

    for subfolder in ds_dir.iterdir():
        """ Iterate through subfolders (1st layer) """
        subfolder_path: Path = ds_dir / subfolder.name
        print(f"In subfolder {subfolder}:")
        
        for class_folder in subfolder_path.iterdir():
            """ Iterate through class folders (2nd layer) """
            if class_folder.is_dir():
                print(f"Processing {class_folder.name}")
                
                hashes: dict[ImageHash, str] = {} # initialize to store hashes for each class
                
                for image_file in class_folder.iterdir():
                    """ Iterate through image files (3rd; last layer) """
                    if image_file.suffix.lower() in EXTENSIONS:
                        try:
                            with Image.open(image_file) as img:
                                img_hash = imagehash.phash(img) # calculate hash based on perceptual hash
                            
                            if img_hash in hashes: # add duplicates in each class to log
                                duplicates_log.setdefault(class_folder.name, []) \
                                .append((str(image_file), hashes[img_hash]))

                                total_duplicates[subfolder.name] += 1  # Increment total duplicate count
                            else: # add new unique image to hashes
                                hashes[img_hash] = str(image_file)
                        except Exception as e:
                            print(f"Error processing {image_file}: {e}")
    print_log(duplicates_log, total_duplicates)

# %%
# check_structure(WHERE_IS_YOUR_DATASET)
check_for_dupes(DATA_DIR)
# Out:
# In subfolder C:\capstone\dataset\raw\garbage_classification:
# Processing battery
# Processing biological
# Processing brown-glass
# Processing cardboard
# Processing clothes
# Processing green-glass
# Processing metal
# Processing paper
# Processing plastic
# Processing shoes
# Processing trash
# Processing white-glass
#
# Duplicate images found:
#
# Class: battery
# Duplicate: C:\capstone\dataset\raw\garbage_classification\battery\battery343.jpg | Original: C:\capstone\dataset\raw\garbage_classification\battery\battery268.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\battery\battery35.jpg | Original: C:\capstone\dataset\raw\garbage_classification\battery\battery129.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\battery\battery833.jpg | Original: C:\capstone\dataset\raw\garbage_classification\battery\battery63.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\battery\battery945.jpg | Original: C:\capstone\dataset\raw\garbage_classification\battery\battery759.jpg
#
# Class: biological
# Duplicate: C:\capstone\dataset\raw\garbage_classification\biological\biological465.jpg | Original: C:\capstone\dataset\raw\garbage_classification\biological\biological404.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\biological\biological698.jpg | Original: C:\capstone\dataset\raw\garbage_classification\biological\biological286.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\biological\biological781.jpg | Original: C:\capstone\dataset\raw\garbage_classification\biological\biological402.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\biological\biological865.jpg | Original: C:\capstone\dataset\raw\garbage_classification\biological\biological410.jpg
#
# Class: brown-glass
# Duplicate: C:\capstone\dataset\raw\garbage_classification\brown-glass\brown-glass439.jpg | Original: C:\capstone\dataset\raw\garbage_classification\brown-glass\brown-glass19.jpg
#
# Class: cardboard
# Duplicate: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard620.jpg | Original: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard532.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard650.jpg | Original: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard527.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard751.jpg | Original: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard501.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard832.jpg | Original: C:\capstone\dataset\raw\garbage_classification\cardboard\cardboard729.jpg
#
# Class: clothes
# Duplicate: C:\capstone\dataset\raw\garbage_classification\clothes\clothes5234.jpg | Original: C:\capstone\dataset\raw\garbage_classification\clothes\clothes2051.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\clothes\clothes536.jpg | Original: C:\capstone\dataset\raw\garbage_classification\clothes\clothes5095.jpg
#
# Class: green-glass
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass410.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass277.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass430.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass210.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass433.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass228.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass443.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass292.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass459.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass388.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass46.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass190.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass461.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass349.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass482.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass422.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass488.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass451.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass492.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass476.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass517.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass413.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass526.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass277.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass530.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass231.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass544.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass471.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass553.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass240.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass554.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass336.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass555.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass285.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass561.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass424.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass563.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass413.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass564.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass403.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass565.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass449.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass592.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass583.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass605.jpg | Original: C:\capstone\dataset\raw\garbage_classification\green-glass\green-glass128.jpg
#
# Class: paper
# Duplicate: C:\capstone\dataset\raw\garbage_classification\paper\paper462.jpg | Original: C:\capstone\dataset\raw\garbage_classification\paper\paper455.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\paper\paper709.jpg | Original: C:\capstone\dataset\raw\garbage_classification\paper\paper705.jpg
#
# Class: plastic
# Duplicate: C:\capstone\dataset\raw\garbage_classification\plastic\plastic506.jpg | Original: C:\capstone\dataset\raw\garbage_classification\plastic\plastic467.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\plastic\plastic829.jpg | Original: C:\capstone\dataset\raw\garbage_classification\plastic\plastic792.jpg
#
# Class: shoes
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1319.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1049.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1390.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1049.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1482.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1065.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1556.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1439.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes421.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1373.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes429.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes322.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes615.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1128.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes621.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes29.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes651.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1065.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\shoes\shoes777.jpg | Original: C:\capstone\dataset\raw\garbage_classification\shoes\shoes1095.jpg
#
# Class: trash
# Duplicate: C:\capstone\dataset\raw\garbage_classification\trash\trash301.jpg | Original: C:\capstone\dataset\raw\garbage_classification\trash\trash238.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\trash\trash315.jpg | Original: C:\capstone\dataset\raw\garbage_classification\trash\trash147.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\trash\trash559.jpg | Original: C:\capstone\dataset\raw\garbage_classification\trash\trash254.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\trash\trash652.jpg | Original: C:\capstone\dataset\raw\garbage_classification\trash\trash413.jpg
# Duplicate: C:\capstone\dataset\raw\garbage_classification\trash\trash665.jpg | Original: C:\capstone\dataset\raw\garbage_classification\trash\trash356.jpg
#
# Total duplicates found per subfolder:
# garbage_classification: 57

# %% [markdown]
# ## DELETE SAID DUPLICATES
# You can see kalo the algorithm is sama

# %%
def copy_if_not_exist(source: Path, destination: Path) -> None:
    if not Path.exists(destination):
        shutil.copy2(source, destination)

def delete_dupes(ds_dir: Path) -> None:
    """Check for duplicate images in the dataset."""
    duplicates_log: dict[str, list[tuple[str, str]]] = {}
    total_duplicates: dict[str, int] = {subfolder.name: 0 for subfolder \
                                        in ds_dir.iterdir() if subfolder.is_dir()}

    for subfolder in ds_dir.iterdir():
        """ Iterate through subfolders (1st layer) """
        subfolder_path: Path = ds_dir / subfolder.name
        cleaned_sub_path: Path = ds_dir.parent / 'dupe_cleaned' / subfolder.name

        print(f"In subfolder {subfolder}:")
        
        for class_folder in subfolder_path.iterdir():
            """ Iterate through class folders (2nd layer) """
            if class_folder.is_dir():
                print(f"Processing {class_folder.name}")

                cleaned_class_path: Path = cleaned_sub_path / class_folder.name
                if not Path.exists(cleaned_class_path): # make dir for dupe-cleaned ds
                    cleaned_class_path.mkdir(parents=True, exist_ok=False)
                
                hashes: dict[ImageHash, str] = {} # initialize to store hashes for each class
                
                for image_file in class_folder.iterdir():
                    """ Iterate through image files (3rd; last layer) """
                    if image_file.suffix.lower() in EXTENSIONS:
                        try:
                            with Image.open(image_file) as img:
                                img_hash = imagehash.phash(img) # calculate hash based on perceptual hash
                            
                            if img_hash not in hashes: #skip copy if in hash (duplicate)
                                destination = cleaned_class_path / image_file.name
                                hashes[img_hash] = str(image_file)
                                copy_if_not_exist(image_file, destination)

                        except Exception as e:
                            print(f"Error processing {image_file}: {e}")

# %%
delete_dupes(DATA_DIR)
# Out:
# In subfolder C:\capstone\dataset\raw\garbage_classification:
# Processing battery
# Processing biological
# Processing brown-glass
# Processing cardboard
# Processing clothes
# Processing green-glass
# Processing metal
# Processing paper
# Processing plastic
# Processing shoes
# Processing trash
# Processing white-glass

# %%
check_for_dupes(DATA_DIR.parent / 'dupe_cleaned')
# Out:
# In subfolder C:\capstone\dataset\dupe_cleaned\garbage_classification:
# Processing battery
# Processing biological
# Processing brown-glass
# Processing cardboard
# Processing clothes
# Processing green-glass
# Processing metal
# Processing paper
# Processing plastic
# Processing shoes
# Processing trash
# Processing white-glass
# No duplicates found in log;               Duplicates log not found

# %% [markdown]
# # Splitting

# %% [markdown]
# ## SPLIT DATASET INTO (TRAIN, VALIDATION AND TEST)
#
# * **WIP: STILL EXPERIMENTAL**

# %% [markdown]
# **ONLY USE THIS CODE IF YOU WANT YOUR DATASET LOOKS LIKE:** <br>
# ```
# dataset
# ├───subfolder_1
# │   ├───train
# │   ├───test
# │   └───validation
# └───subfolder_n
#     ├───train
#     ├───test
#     └───validation
# ```
# **Note:** Classes inside your splitted dataset will remain the same <br>
# Example: `dataset/subfolder/train/class_n`

# %%
""" GLOBAL VARIABLES FOR SPLITTING """
CLEAN_DS_DIR: Path = DATA_DIR.parent / 'dupe_cleaned'
SPLIT_RATIOS: dict[str, float] = {'train': 0.7, 'validation': 0.2, 'test': 0.1}

# %%
def copy_if_not_exist(source: Path, destination: Path) -> None:
    if not Path.exists(destination):
        shutil.copy2(source, destination)

def split_files(files: list[Path]) -> dict[str, list[Path]]:
    """ This function splits the dataset using the list index """
    random.seed(42)
    random.shuffle(files)
    train_i_end: int = int(len(files) * SPLIT_RATIOS['train'])
    val_i_end: int = train_i_end + int(len(files) * SPLIT_RATIOS['validation'])
    return {
        'train': files[:train_i_end],
        'validation': files[train_i_end:val_i_end],
        'test': files[val_i_end:]
    }

def split_dataset(clean_ds_dir: Path) -> None:
    for subfolder in clean_ds_dir.iterdir():
        """ Iterate through subfolders (1st layer) """
        subfolder_path: Path = CLEAN_DS_DIR / subfolder.name
        split_path: Path = CLEAN_DS_DIR.parent / 'split'

        print(f"In subfolder {subfolder}:")
        for class_folder in subfolder_path.iterdir():
            """ Iterate through class folders (2nd layer) """
            if class_folder.is_dir():
                print(f"Processing {class_folder.name}")
                
                files = [ file for file in class_folder.iterdir() # iterate through files in 
                         if file.suffix.lower() in EXTENSIONS ]   # class folders;
                files = split_files(files)                        # store and split files
                
                for split, files in files.items():
                    destination_path: Path = split_path / subfolder.name / split /class_folder.name
                    if not Path.exists(destination_path):
                        destination_path.mkdir(parents=True, exist_ok=False)
                    for file_path in files:
                        destination = destination_path / file_path.name
                        copy_if_not_exist(file_path, destination)

# %%
split_dataset(CLEAN_DS_DIR)
# Out:
# In subfolder C:\capstone\dataset\dupe_cleaned\garbage_classification:
# Processing battery
# Processing biological
# Processing brown-glass
# Processing cardboard
# Processing clothes
# Processing green-glass
# Processing metal
# Processing paper
# Processing plastic
# Processing shoes
# Processing trash
# Processing white-glass

# %% [markdown]
# # CHECK TRAIN, TEST, VALIDATION FOR DUPES
# * **WIP: STILL EXPERIMENTAL**
# * **MANUAL**

# %%
# def check_for_data_leakage():
#     # Dictionary to store image hashes and their associated file paths and dataset type
#     hash_dict = {}
#     # Dictionary to store leaks found between datasets
#     data_leakage_log = {subfolder: [] for subfolder in SUB_DIRS}

#     # Iterate through each folder in train, validation, and test
#     for subfolder in SUB_DIRS:
#         subfolder_path = DATA_DIR / subfolder
#         print(f"Checking for data leakage in '{subfolder}' set...")

#         # Iterate through each class folder
#         for class_folder in subfolder_path.iterdir():
#             if class_folder.is_dir():
#                 # Iterate through images in the class folder
#                 for image_file in class_folder.iterdir():
#                     if image_file.suffix.lower() in EXTENSIONS:
#                         try:
#                             # Open image and calculate hash
#                             with Image.open(image_file) as img:
#                                 img_hash = imagehash.phash(img)

#                             # Check if this hash already exists in another dataset
#                             if img_hash in hash_dict:
#                                 # Check if it came from a different subset
#                                 if hash_dict[img_hash]['subfolder'] != subfolder:
#                                     data_leakage_log[subfolder].append((image_file, hash_dict[img_hash]['path']))
#                                     print(f"Duplicates: {image_file} (in '{subfolder}') | {hash_dict[img_hash]['path']} (in '{hash_dict[img_hash]['subfolder']}')")
#                             else:
#                                 # If the hash is unique so far, store it with the file path and subfolder
#                                 hash_dict[img_hash] = {'path': image_file, 'subfolder': subfolder}
#                         except Exception as e:
#                             print(f"Error processing {image_file}: {e}")

#     # # Output data leakage log if any leaks are found
#     # if any(data_leakage_log[subfolder] for subfolder in SUB_DIRS):
#     #     print("\nData leakage detected across datasets:")
#     #     for subfolder, leakage_pairs in data_leakage_log.items():
#     #         if leakage_pairs:
#     #             print(f"\nLeakage in '{subfolder}' set:")
#     #             for duplicate, original in leakage_pairs:
#     #                 print(f"Duplicate in {duplicate} matches with {original}")
#     # else:
#     #     print("No data leakage found between train, validation, and test sets.")

# # Execute the function
# check_for_data_leakage()
# Out:
# Checking for data leakage in 'test' set...
# Checking for data leakage in 'train' set...
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_103.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\steel_food_cans\Image_113.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_115.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\steel_food_cans\Image_104.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_6.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\steel_food_cans\Image_5.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_121.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_25.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_144.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_100.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_18.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_185.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_195.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_118.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_46.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_137.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_5.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_90.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_61.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_59.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_105.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_248.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_117.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_56.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_148.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_81.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_168.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_140.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_181.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_106.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_211.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_182.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_216.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_167.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_96.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_113.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\glass_food_jars\Image_152.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\glass_cosmetic_containers\Image_162.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\paper_cups\Image_64.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\plastic_cup_lids\Image_120.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_cup_lids\Image_1.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\paper_cups\Image_88.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_cup_lids\Image_244.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\paper_cups\Image_165.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_cup_lids\Image_36.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\paper_cups\Image_105.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_cup_lids\Image_4.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\paper_cups\Image_210.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_food_containers\Image_176.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\plastic_cup_lids\Image_184.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_soda_bottles\Image_30.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\glass_beverage_bottles\Image_65.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\steel_food_cans\Image_214.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\aluminum_food_cans\Image_39.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\steel_food_cans\Image_32.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\aluminum_food_cans\Image_74.png (in 'test')
# Checking for data leakage in 'validation' set...
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\aluminum_food_cans\Image_10.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\steel_food_cans\Image_28.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\aluminum_food_cans\Image_111.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_soda_cans\Image_11.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\aluminum_food_cans\Image_151.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\aluminum_soda_cans\Image_34.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\aluminum_food_cans\Image_2.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\steel_food_cans\Image_92.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\aluminum_food_cans\Image_56.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\steel_food_cans\Image_133.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\aluminum_food_cans\Image_80.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_soda_cans\Image_202.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\aluminum_soda_cans\Image_182.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_131.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_103.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_182.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_116.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_173.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_124.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_129.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_15.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_16.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_197.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_222.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_214.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_70.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_235.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_141.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_240.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_232.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_245.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_233.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_29.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_85.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_3.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_5.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_37.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_46.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_42.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_175.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_69.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_165.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_77.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_packaging\Image_35.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_8.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_174.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_boxes\Image_88.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_packaging\Image_188.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_10.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_21.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_104.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_64.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_119.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_23.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_12.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_17.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_13.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_10.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_133.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_212.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_14.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_12.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_156.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_48.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_162.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_198.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_180.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_68.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_71.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\cardboard_boxes\Image_178.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_82.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_188.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\cardboard_packaging\Image_84.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\cardboard_boxes\Image_241.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\glass_cosmetic_containers\Image_93.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_food_containers\Image_183.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\paper_cups\Image_118.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_cup_lids\Image_15.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\plastic_cup_lids\Image_150.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\paper_cups\Image_249.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\plastic_shopping_bags\Image_1.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_trash_bags\Image_54.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\plastic_shopping_bags\Image_22.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_trash_bags\Image_207.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\plastic_soda_bottles\Image_60.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_water_bottles\Image_22.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\plastic_trash_bags\Image_159.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\plastic_shopping_bags\Image_102.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\plastic_water_bottles\Image_100.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\glass_beverage_bottles\Image_65.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\steel_food_cans\Image_112.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_50.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\steel_food_cans\Image_147.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_61.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\steel_food_cans\Image_164.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_47.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\styrofoam_cups\Image_46.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\paper_cups\Image_9.png (in 'train')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\validation\styrofoam_food_containers\Image_21.png (in 'validation') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\plastic_food_containers\Image_87.png (in 'test')
